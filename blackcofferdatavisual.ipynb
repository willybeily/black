# %%
import json 
import csv

# %%
with open('data.json',encoding="utf8") as json_file: 
    data = json.load(json_file)

# %%
data
# Out:
# [{'end_year': '',
#   'intensity': 6,
#   'sector': 'Energy',
#   'topic': 'gas',
#   'insight': 'Annual Energy Outlook',
#   'url': 'http://www.eia.gov/outlooks/aeo/pdf/0383(2017).pdf',
#   'region': 'Northern America',
#   'start_year': '',
#   'impact': '',
#   'added': 'January, 20 2017 03:51:25',
#   'published': 'January, 09 2017 00:00:00',
#   'country': 'United States of America',
#   'relevance': 2,
#   'pestle': 'Industries',
#   'source': 'EIA',
#   'title': 'U.S. natural gas consumption is expected to increase during much of the projection period.',
#   'likelihood': 3},
#  {'end_year': '',
#   'intensity': 6,
#   'sector': 'Energy',
#   'topic': 'oil',
#   'insight': 'Annual Energy Outlook',
#   'url': 'http://www.eia.gov/outlooks/aeo/pdf/0383(2017).pdf',
#   'region': 'Northern America',
#   'start_year': '',
#   'impact': '',
#   'added': 'January, 20 2017 03:51:24',
#   'published': 'January, 09 2017 00:00:00',
#   'country': 'United States of America',
# ...

# %%
data_file = open('data_file.csv', 'w',encoding="utf8")

# %%
csv_writer = csv.writer(data_file)

# %%
count = 0
  
for inf in data: 
    if count == 0: 
  
        # Writing headers of CSV file 
        header = inf.keys() 
        csv_writer.writerow(header) 
        count += 1
  
    # Writing data of CSV file 
    csv_writer.writerow(inf.values()) 
  
data_file.close()

# %%
import pandas

# %%
import pandas as pd

df = pd.read_csv ('data_file.csv')

# %%
df.head()
# Out:
#    end_year  intensity       sector        topic  \
# 0       NaN        6.0       Energy          gas
# 1       NaN        6.0       Energy          oil
# 2       NaN        6.0       Energy  consumption
# 3       NaN        6.0  Environment          oil
# 4       NaN        6.0          NaN       market
#
#                                              insight  \
# 0                              Annual Energy Outlook
# 1                              Annual Energy Outlook
# 2                              Annual Energy Outlook
# 3  WRI Partnership Aims to Foster Supply Chain Tr...
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
#
#                                                  url            region  \
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# ...

# %%
df.isnull()
# Out:
#      end_year  intensity  sector  topic  insight    url  region  start_year  \
# 0        True      False   False  False    False  False   False        True
# 1        True      False   False  False    False  False   False        True
# 2        True      False   False  False    False  False   False        True
# 3        True      False   False  False    False  False   False        True
# 4        True      False    True  False    False  False   False        True
# ..        ...        ...     ...    ...      ...    ...     ...         ...
# 995      True      False   False  False    False  False    True        True
# 996     False       True   False  False    False  False   False        True
# 997      True      False    True  False    False  False    True       False
# 998     False      False   False  False    False  False    True        True
# 999      True      False    True   True    False  False   False        True
#
# ...

# %%
pd.isnull(df['end_year']).sum()
# Out:
# 742

# %%
df.shape
# Out:
# (1000, 17)

# %%
pd.isnull(df['impact']).sum()
# Out:
# 966

# %%
df.drop(["end_year","impact"], axis = 1, inplace = True)

# %%
df
# Out:
#      intensity              sector        topic  \
# 0          6.0              Energy          gas
# 1          6.0              Energy          oil
# 2          6.0              Energy  consumption
# 3          6.0         Environment          oil
# 4          6.0                 NaN       market
# ..         ...                 ...          ...
# 995        2.0  Financial services          oil
# 996        NaN       Manufacturing       growth
# 997       16.0                 NaN       growth
# 998        3.0              Retail       export
# 999        2.0                 NaN          NaN
#
#                                                insight  \
# 0                                Annual Energy Outlook
# 1                                Annual Energy Outlook
# 2                                Annual Energy Outlook
# 3    WRI Partnership Aims to Foster Supply Chain Tr...
# 4    N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
# ...

# %%
df.head()
# Out:
#    intensity       sector        topic  \
# 0        6.0       Energy          gas
# 1        6.0       Energy          oil
# 2        6.0       Energy  consumption
# 3        6.0  Environment          oil
# 4        6.0          NaN       market
#
#                                              insight  \
# 0                              Annual Energy Outlook
# 1                              Annual Energy Outlook
# 2                              Annual Energy Outlook
# 3  WRI Partnership Aims to Foster Supply Chain Tr...
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
#
#                                                  url            region  \
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 3  http://www.sustainablebrands.com/news_and_view...   Central America
# ...

# %%
df.drop(['url'], axis=1,inplace=True)

# %%
pd.isnull(df['start_year']).sum()
# Out:
# 690

# %%
df.drop(['start_year'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    intensity       sector        topic  \
# 0        6.0       Energy          gas
# 1        6.0       Energy          oil
# 2        6.0       Energy  consumption
# 3        6.0  Environment          oil
# 4        6.0          NaN       market
#
#                                              insight            region  \
# 0                              Annual Energy Outlook  Northern America
# 1                              Annual Energy Outlook  Northern America
# 2                              Annual Energy Outlook  Northern America
# 3  WRI Partnership Aims to Foster Supply Chain Tr...   Central America
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...             World
#
#                        added                  published  \
# 0  January, 20 2017 03:51:25  January, 09 2017 00:00:00
# 1  January, 20 2017 03:51:24  January, 09 2017 00:00:00
# 2  January, 20 2017 03:51:23  January, 09 2017 00:00:00
# 3  January, 20 2017 03:26:40  January, 18 2017 00:00:00
# ...

# %%
df.head()
# Out:
#    intensity       sector        topic  \
# 0        6.0       Energy          gas
# 1        6.0       Energy          oil
# 2        6.0       Energy  consumption
# 3        6.0  Environment          oil
# 4        6.0          NaN       market
#
#                                              insight            region  \
# 0                              Annual Energy Outlook  Northern America
# 1                              Annual Energy Outlook  Northern America
# 2                              Annual Energy Outlook  Northern America
# 3  WRI Partnership Aims to Foster Supply Chain Tr...   Central America
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...             World
#
#                        added                  published  \
# 0  January, 20 2017 03:51:25  January, 09 2017 00:00:00
# 1  January, 20 2017 03:51:24  January, 09 2017 00:00:00
# 2  January, 20 2017 03:51:23  January, 09 2017 00:00:00
# 3  January, 20 2017 03:26:40  January, 18 2017 00:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), center=0, cmap='Blues')
ax.set_title('data visualisation')
# Out:
# Text(0.5, 1, 'data visualisation')

# %%
df
# Out:
#      intensity              sector        topic  \
# 0          6.0              Energy          gas
# 1          6.0              Energy          oil
# 2          6.0              Energy  consumption
# 3          6.0         Environment          oil
# 4          6.0                 NaN       market
# ..         ...                 ...          ...
# 995        2.0  Financial services          oil
# 996        NaN       Manufacturing       growth
# 997       16.0                 NaN       growth
# 998        3.0              Retail       export
# 999        2.0                 NaN          NaN
#
#                                                insight            region  \
# 0                                Annual Energy Outlook  Northern America
# 1                                Annual Energy Outlook  Northern America
# 2                                Annual Energy Outlook  Northern America
# 3    WRI Partnership Aims to Foster Supply Chain Tr...   Central America
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
  
le = LabelEncoder() 
df.dropna(axis=0,inplace=True)
df['sector']= le.fit_transform(df['sector']) 
df['topic']= le.fit_transform(df['topic']) 
df['insight']=le.fit_transform(df['insight'])
df['region']=le.fit_transform(df['region'])
df['added']=le.fit_transform(df['added'])
df['pestle']=le.fit_transform(df['pestle'])
df['source']=le.fit_transform(df['source'])
df['country']=le.fit_transform(df['country'])

# %%
fig, ax = plt.subplots(figsize=(20,16))
sns.heatmap(df.corr(), center=0, cmap='YlGnBu')
ax.set_title('data visualisation')
# Out:
# Text(0.5, 1, 'data visualisation')
